# %%
import pandas as pd 
ecu = pd.read_csv(r'/Users/mac/Downloads/sheet.csv')
ecu
# Out:
#       TIME   BASE FUEL (PERCENTAGE)  BASE IGNITION (ANGLE ON SPRT 2K)  \
# 0   8:27:27                     NaN                               NaN
# 1   8:27:27                   356.0                             324.0
# 2   8:27:27                   354.0                             324.0
# 3   8:27:27                   353.0                             326.0
# 4   8:27:27                   356.0                             324.0
# 5   8:27:27                   358.0                             321.0
# 6   8:27:27                   361.0                             317.0
# 7   8:27:27                     NaN                               NaN
# 8   8:27:27                   359.0                             317.0
# 9   8:27:27                   353.0                             324.0
# 10  8:27:27                     NaN                               NaN
# 11  8:27:27                   356.0                             322.0
# ...

# %%
y = ecu.DISTANCELATERALW
print(y)
# Out:
# 0     0.98
# 1     1.10
# 2     0.99
# 3     0.90
# 4     0.98
# 5     1.09
# 6     1.25
# 7     0.93
# 8     0.92
# 9     0.95
# 10    0.95
# 11    0.67
# 12    0.92
# 13    0.95
# 14    0.98
# 15    0.95
# 16    0.91
# 17    0.95
# 18    0.52
# 19    0.50
# 20    0.97
# 21    1.10
# 22    0.84
# 23    1.23
# 24    1.10
# 25    1.32
# 26    1.08
# 27    0.95
# 28    1.10
# 29    0.96
# 30    0.85
# 31    0.87
# 32    0.79
# 33    0.80
# 34    0.96
# Name: DISTANCELATERALW, dtype: float64

# %%
z = ecu['DISTANCELATERALW'].describe()
z
# Out:
# count    35.000000
# mean      0.951714
# std       0.170233
# min       0.500000
# 25%       0.905000
# 50%       0.950000
# 75%       1.035000
# max       1.320000
# Name: DISTANCELATERALW, dtype: float64

# %%
ecu.head()
# Out:
#      TIME   BASE FUEL (PERCENTAGE)  BASE IGNITION (ANGLE ON SPRT 2K)  \
# 0  8:27:27                     NaN                               NaN
# 1  8:27:27                   356.0                             324.0
# 2  8:27:27                   354.0                             324.0
# 3  8:27:27                   353.0                             326.0
# 4  8:27:27                   356.0                             324.0
#
#    TARGET AFR(AFR)  FUEL COOLANT TEMPERATURE CORRECTION(% 1 0N 1 )  \
# 0              NaN                                             NaN
# 1              NaN                                             NaN
# 2              NaN                                             NaN
# 3              NaN                                             NaN
# 4              NaN                                             NaN
#
#    FUEL AIR TEMP.CORRECTION(%)  THROTTLE POSITION(%)  \
# 0                          NaN                   NaN
# ...

# %%
x = ecu[['SPEED']]
print(x)
# Out:
#     SPEED
# 0      45
# 1      60
# 2      55
# 3      40
# 4      45
# 5      47
# 6      45
# 7      40
# 8      40
# 9      42
# 10     40
# 11     25
# 12     30
# 13     35
# 14     45
# 15     40
# 16     43
# 17     40
# 18     15
# 19     10
# 20     45
# 21     60
# 22     29
# 23     65
# 24     60
# 25     68
# 26     58
# 27     40
# 28     60
# 29     43
# 30     31
# 31     45
# 32     35
# 33     39
# 34     41

# %%
from sklearn.tree import DecisionTreeRegressor
ecu_model = DecisionTreeRegressor()
ecu_model.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(x, y, random_state=1)

# %%
ecu_model = DecisionTreeRegressor(random_state = 1)
ecu_model.fit(train_X,train_y)
ecu_predictions = ecu_model.predict(val_X)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(14,6))

sns.barplot(x = ecu['SPEED'], y = ecu.DISTANCELATERALW)
plt.figure(figsize=(14,6))
sns.barplot(x = ecu['SPEED'], y = ecu.DISTANCELON)

# %%
plt.figure(figsize=(14,6))

sns.lineplot(x = ecu['SPEED'], y = ecu.DISTANCELATERALW)
sns.lineplot(x = ecu['SPEED'], y = ecu.DISTANCELON)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELATERALW)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELON)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELONAUTO)
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELONHV)
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELON)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELATAUTO)

# %%
w = ecu['DISTANCELATAUTO'].describe()
w
# Out:
# count    35.000000
# mean      1.130000
# std       0.250012
# min       0.600000
# 25%       0.960000
# 50%       1.230000
# 75%       1.290000
# max       1.580000
# Name: DISTANCELATAUTO, dtype: float64

# %%
m = ecu['DISTANCELATHV'].describe()
m
# Out:
# count    35.00000
# mean      0.80200
# std       0.13317
# min       0.45000
# 25%       0.73500
# 50%       0.82000
# 75%       0.88500
# max       1.10000
# Name: DISTANCELATHV, dtype: float64

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELATHV)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELONHV)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELONTW)

# %%
sns.scatterplot(x = ecu['SPEED'], y = ecu.DISTANCELATTW)
