# %%
import pandas as pd 
ecu = pd.read_csv(r'/Users/mac/Downloads/final sheet.csv')
ecu
# Out:
#       TIME   BASE FUEL (PERCENTAGE)  BASE IGNITION (ANGLE ON SPRT 2K)  \
# 0   8:27:27                     NaN                               NaN
# 1   8:27:27                   356.0                             324.0
# 2   8:27:27                   354.0                             324.0
# 3   8:27:27                   353.0                             326.0
# 4   8:27:27                   356.0                             324.0
# 5   8:27:27                   358.0                             321.0
# 6   8:27:27                   361.0                             317.0
# 7   8:27:27                     NaN                               NaN
# 8   8:27:27                   359.0                             317.0
# 9   8:27:27                   353.0                             324.0
# 10  8:27:27                     NaN                               NaN
# 11  8:27:27                   356.0                             322.0
# 12  8:27:27                   360.0                             320.0
# 13  8:27:27                   364.0                             316.0
# 14  8:27:27                   361.0                             317.0
# 15  8:27:27                     NaN                               NaN
# 16  8:27:29                     NaN                               NaN
# 17  8:27:29                   349.0                             320.0
# 18  8:27:29                   351.0                             320.0
# 19  8:27:29                   347.0                             323.0
# 20  8:27:29                   347.0                             325.0
# 21  8:27:29                   352.0                             322.0
# 22  8:27:29                   352.0                             323.0
# 23  8:27:29                   353.0                             322.0
# 24  8:27:29                   351.0                             321.0
# 25  8:27:29                   349.0                             322.0
# 26  8:27:29                   353.0                             320.0
# 27  8:27:30                   351.0                             320.0
# 28  8:27:30                   348.0                             321.0
# 29  8:27:30                   348.0                             321.0
# 30  8:27:30                   349.0                             320.0
# 31  8:27:30                   348.0                             321.0
# 32  8:27:30                   348.0                             322.0
# 33  8:27:30                   351.0                             320.0
# 34  8:27:30                   347.0                             321.0
#
#     TARGET AFR(AFR)  FUEL COOLANT TEMPERATURE CORRECTION(% 1 0N 1 )  \
# 0               NaN                                             NaN
# 1               NaN                                             NaN
# 2               NaN                                             NaN
# 3               NaN                                             NaN
# 4               NaN                                             NaN
# 5               NaN                                             NaN
# 6               NaN                                             NaN
# 7               NaN                                             NaN
# 8               NaN                                             NaN
# 9               NaN                                             NaN
# 10              NaN                                             NaN
# 11              NaN                                             NaN
# 12              NaN                                             NaN
# 13              NaN                                             NaN
# 14              NaN                                             NaN
# 15              NaN                                             NaN
# 16              NaN                                             NaN
# 17              NaN                                             NaN
# 18              NaN                                             NaN
# 19              NaN                                             NaN
# 20              NaN                                             NaN
# 21              NaN                                             NaN
# 22              NaN                                             NaN
# 23              NaN                                             NaN
# 24              NaN                                             NaN
# 25              NaN                                             NaN
# 26              NaN                                             NaN
# 27              NaN                                             NaN
# 28              NaN                                             NaN
# 29              NaN                                             NaN
# 30              NaN                                             NaN
# 31              NaN                                             NaN
# 32              NaN                                             NaN
# 33              NaN                                             NaN
# 34              NaN                                             NaN
#
#     FUEL AIR TEMP.CORRECTION(%)  THROTTLE POSITION(%)  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
# 6                           NaN                   NaN
# 7                           NaN                   NaN
# 8                           NaN                   NaN
# 9                           NaN                   NaN
# 10                          NaN                   NaN
# 11                          NaN                   NaN
# 12                          NaN                   NaN
# 13                          NaN                   NaN
# 14                          NaN                   NaN
# 15                          NaN                   NaN
# 16                          NaN                   NaN
# 17                          NaN                   NaN
# 18                          NaN                   NaN
# 19                          NaN                   NaN
# 20                          NaN                   NaN
# 21                          NaN                   NaN
# 22                          NaN                   NaN
# 23                          NaN                   NaN
# 24                          NaN                   NaN
# 25                          NaN                   NaN
# 26                          NaN                   NaN
# 27                          NaN                   NaN
# 28                          NaN                   NaN
# 29                          NaN                   NaN
# 30                          NaN                   NaN
# 31                          NaN                   NaN
# 32                          NaN                   NaN
# 33                          NaN                   2.0
# 34                          NaN                   3.0
#
#     AIR TEMPERATURE(TEMPERATURE)  COOLANT TEMPERATURE (TEMPERATURE)  \
# 0                            NaN                                NaN
# 1                         3076.0                             3310.0
# 2                         3075.0                             3310.0
# 3                         3076.0                             3309.0
# 4                            NaN                                NaN
# 5                            NaN                                NaN
# 6                         3076.0                             3309.0
# 7                            NaN                                NaN
# 8                         3075.0                             3310.0
# 9                         3076.0                             3309.0
# 10                           NaN                                NaN
# 11                        3075.0                             3310.0
# 12                        3076.0                             3309.0
# 13                           NaN                             3309.0
# 14                           NaN                             3310.0
# 15                           NaN                                NaN
# 16                           NaN                                NaN
# 17                           NaN                                NaN
# 18                           NaN                                NaN
# 19                           NaN                                NaN
# 20                           NaN                                NaN
# 21                           NaN                                NaN
# 22                           NaN                                NaN
# 23                           NaN                                NaN
# 24                           NaN                                NaN
# 25                           NaN                                NaN
# 26                           NaN                                NaN
# 27                        3076.0                                NaN
# 28                           NaN                                NaN
# 29                           NaN                                NaN
# 30                           NaN                                NaN
# 31                        3076.0                                NaN
# 32                        3077.0                                NaN
# 33                        3076.0                                NaN
# 34                        3077.0                                NaN
#
#     LAMBDASENSOR  ...  ENGINE RUNNING TIME (S)  DELTA LOAD (%)  \
# 0            964  ...                      NaN             0.0
# 1            962  ...                      NaN            -1.0
# 2            963  ...                      NaN             0.0
# 3            962  ...                      NaN             NaN
# 4            961  ...                      NaN             NaN
# 5            964  ...                      NaN             NaN
# 6            963  ...                      NaN             NaN
# 7            956  ...                      NaN             NaN
# 8            965  ...                    152.0             NaN
# 9            963  ...                    153.0             NaN
# 10           965  ...                      NaN             NaN
# 11           963  ...                      NaN             NaN
# 12           963  ...                      NaN             NaN
# 13           964  ...                      NaN             NaN
# 14           958  ...                      NaN             NaN
# 15           945  ...                      NaN             0.0
# 16           944  ...                      NaN             NaN
# 17           954  ...                      NaN             NaN
# 18           956  ...                      NaN             0.0
# 19           952  ...                      NaN            -1.0
# 20           948  ...                      NaN             0.0
# 21           949  ...                      NaN             0.0
# 22           950  ...                      NaN            -1.0
# 23           949  ...                      NaN             0.0
# 24           952  ...                      NaN             NaN
# 25           954  ...                      NaN             NaN
# 26           955  ...                    154.0             NaN
# 27           961  ...                      NaN             0.0
# 28           961  ...                      NaN             NaN
# 29           962  ...                      NaN             NaN
# 30           962  ...                      NaN             NaN
# 31           960  ...                      NaN             NaN
# 32           963  ...                    155.0             NaN
# 33           962  ...                    156.0             NaN
# 34           965  ...                      NaN             NaN
#
#     MAP SOURCE (PRESSURE)  TRANSIENT THROTTLE LOAD SOURCE(%)  \
# 0                   421.0                                NaN
# 1                   424.0                                NaN
# 2                   423.0                                NaN
# 3                   423.0                                NaN
# 4                   424.0                                NaN
# 5                   424.0                                NaN
# 6                   425.0                                NaN
# 7                     NaN                                NaN
# 8                   422.0                                NaN
# 9                   421.0                                NaN
# 10                  423.0                                NaN
# 11                  422.0                                NaN
# 12                  425.0                                NaN
# 13                  424.0                                NaN
# 14                  422.0                                NaN
# 15                  420.0                                2.0
# 16                  412.0                                NaN
# 17                  411.0                                NaN
# 18                    NaN                                NaN
# 19                  411.0                                NaN
# 20                  413.0                                NaN
# 21                  417.0                                NaN
# 22                  418.0                                NaN
# 23                  418.0                                NaN
# 24                  415.0                                NaN
# 25                  415.0                                NaN
# 26                  417.0                                NaN
# 27                  409.0                                NaN
# 28                  411.0                                NaN
# 29                  410.0                                NaN
# 30                  410.0                                NaN
# 31                  412.0                                NaN
# 32                  410.0                                NaN
# 33                  409.0                                NaN
# 34                  407.0                                NaN
#
#     IGNITION LOAD (PRESSURE)  DISTANCE  DISTANCELAT  AFRDIFFERENCE  \
# 0                      423.0      5.70          2.6             32
# 1                      423.0    170.00          3.7             38
# 2                      422.0    150.00          3.6             37
# 3                      422.0     17.00          3.9             38
# 4                      424.0      6.98          2.8             39
# 5                        NaN     20.00          2.4             36
# 6                      424.0     90.00          3.9             37
# 7                        NaN      8.89          2.6             37
# 8                      422.0     89.00          2.6             35
# 9                      420.0      7.89          2.4             37
# 10                     422.0     78.00          3.7             41
# 11                     422.0      9.70          2.7             37
# 12                     425.0      8.80          2.3             37
# 13                     424.0      5.60          2.7             36
# 14                     422.0      4.50          3.6             42
# 15                     419.0    150.00          3.9             34
# 16                     412.0     34.00          3.2             46
# 17                     409.0      9.80          2.8             46
# 18                     413.0    134.00          3.8             44
# 19                     412.0    145.00          3.9             48
# 20                     414.0      5.60          2.4             52
# 21                     417.0    123.00          3.7             51
# 22                     418.0     89.00          3.8             50
# 23                     418.0     98.00          2.9             51
# 24                     415.0     76.00          2.3             48
# 25                     414.0    145.00          3.8             46
# 26                     417.0    156.00          3.4             45
# 27                     409.0    123.00          3.8             39
# 28                     410.0      5.60          2.3             39
# 29                     409.0      4.50          2.4             38
# 30                     412.0      7.60          2.7             38
# 31                     412.0     89.00          3.6             40
# 32                     409.0      3.40          2.8             37
# 33                     410.0      4.50          2.9             38
# 34                     408.0      6.70          2.6             36
#
#     STEERINGANGLE  SPEED
# 0            50.9     45
# 1            10.0     60
# 2             0.0     55
# 3             0.0     40
# 4            40.9     45
# 5            34.5     47
# 6            15.6     45
# 7            45.9     40
# 8            36.7     40
# 9            57.0     42
# 10           23.4     40
# 11           67.0     45
# 12           59.8     45
# 13           60.8     35
# 14           46.8     45
# 15           15.9     40
# 16           46.7     43
# 17           50.9     40
# 18           10.5     60
# 19            0.8     65
# 20           56.7     45
# 21           23.3     60
# 22           23.4     55
# 23           23.3     65
# 24           45.8     60
# 25            1.4     68
# 26           12.5     58
# 27           36.7     41
# 28           57.8     60
# 29           45.6     43
# 30           56.7     44
# 31           15.7     45
# 32           45.7     49
# 33           67.8     39
# 34           45.7     41
#
# [35 rows x 23 columns]

# %%
y = ecu.STEERINGANGLE
print(y)
# Out:
# 0     50.9
# 1     10.0
# 2      0.0
# 3      0.0
# 4     40.9
# 5     34.5
# 6     15.6
# 7     45.9
# 8     36.7
# 9     57.0
# 10    23.4
# 11    67.0
# 12    59.8
# 13    60.8
# 14    46.8
# 15    15.9
# 16    46.7
# 17    50.9
# 18    10.5
# 19     0.8
# 20    56.7
# 21    23.3
# 22    23.4
# 23    23.3
# 24    45.8
# 25     1.4
# 26    12.5
# 27    36.7
# 28    57.8
# 29    45.6
# 30    56.7
# 31    15.7
# 32    45.7
# 33    67.8
# 34    45.7
# Name: STEERINGANGLE, dtype: float64

# %%
z = ecu['STEERINGANGLE'].describe()
z
# Out:
# count    35.000000
# mean     35.205714
# std      20.906443
# min       0.000000
# 25%      15.800000
# 50%      40.900000
# 75%      50.900000
# max      67.800000
# Name: STEERINGANGLE, dtype: float64

# %%
ecu.head()
# Out:
#      TIME   BASE FUEL (PERCENTAGE)  BASE IGNITION (ANGLE ON SPRT 2K)  \
# 0  8:27:27                     NaN                               NaN
# 1  8:27:27                   356.0                             324.0
# 2  8:27:27                   354.0                             324.0
# 3  8:27:27                   353.0                             326.0
# 4  8:27:27                   356.0                             324.0
#
#    TARGET AFR(AFR)  FUEL COOLANT TEMPERATURE CORRECTION(% 1 0N 1 )  \
# 0              NaN                                             NaN
# 1              NaN                                             NaN
# 2              NaN                                             NaN
# 3              NaN                                             NaN
# 4              NaN                                             NaN
#
#    FUEL AIR TEMP.CORRECTION(%)  THROTTLE POSITION(%)  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
#
#    AIR TEMPERATURE(TEMPERATURE)  COOLANT TEMPERATURE (TEMPERATURE)  \
# 0                           NaN                                NaN
# 1                        3076.0                             3310.0
# 2                        3075.0                             3310.0
# 3                        3076.0                             3309.0
# 4                           NaN                                NaN
#
#    LAMBDASENSOR  ...  ENGINE RUNNING TIME (S)  DELTA LOAD (%)  \
# 0           964  ...                      NaN             0.0
# 1           962  ...                      NaN            -1.0
# 2           963  ...                      NaN             0.0
# 3           962  ...                      NaN             NaN
# 4           961  ...                      NaN             NaN
#
#    MAP SOURCE (PRESSURE)  TRANSIENT THROTTLE LOAD SOURCE(%)  \
# 0                  421.0                                NaN
# 1                  424.0                                NaN
# 2                  423.0                                NaN
# 3                  423.0                                NaN
# 4                  424.0                                NaN
#
#    IGNITION LOAD (PRESSURE)  DISTANCE  DISTANCELAT  AFRDIFFERENCE  \
# 0                     423.0      5.70          2.6             32
# 1                     423.0    170.00          3.7             38
# 2                     422.0    150.00          3.6             37
# 3                     422.0     17.00          3.9             38
# 4                     424.0      6.98          2.8             39
#
#    STEERINGANGLE  SPEED
# 0           50.9     45
# 1           10.0     60
# 2            0.0     55
# 3            0.0     40
# 4           40.9     45
#
# [5 rows x 23 columns]

# %%
x = ecu[['LAMBDASENSOR','RPM','DISTANCE','AFRDIFFERENCE','DISTANCELAT', 'SPEED']]
print(x)
# Out:
#     LAMBDASENSOR   RPM  DISTANCE  AFRDIFFERENCE  DISTANCELAT  SPEED
# 0            964   962      5.70             32          2.6     45
# 1            962  2666    170.00             38          3.7     60
# 2            963  2445    150.00             37          3.6     55
# 3            962   930     17.00             38          3.9     40
# 4            961   941      6.98             39          2.8     45
# 5            964   964     20.00             36          2.4     47
# 6            963  2667     90.00             37          3.9     45
# 7            956  1004      8.89             37          2.6     40
# 8            965  2665     89.00             35          2.6     40
# 9            963  1004      7.89             37          2.4     42
# 10           965  2665     78.00             41          3.7     40
# 11           963   964      9.70             37          2.7     45
# 12           963   972      8.80             37          2.3     45
# 13           964  1012      5.60             36          2.7     35
# 14           958  1014      4.50             42          3.6     45
# 15           945  2665    150.00             34          3.9     40
# 16           944   987     34.00             46          3.2     43
# 17           954  1001      9.80             46          2.8     40
# 18           956  2556    134.00             44          3.8     60
# 19           952  2568    145.00             48          3.9     65
# 20           948  2667      5.60             52          2.4     45
# 21           949  2667    123.00             51          3.7     60
# 22           950  2667     89.00             50          3.8     55
# 23           949  2667     98.00             51          2.9     65
# 24           952  2667     76.00             48          2.3     60
# 25           954  2667    145.00             46          3.8     68
# 26           955  2667    156.00             45          3.4     58
# 27           961  2667    123.00             39          3.8     41
# 28           961   999      5.60             39          2.3     60
# 29           962   999      4.50             38          2.4     43
# 30           962  1000      7.60             38          2.7     44
# 31           960  2897     89.00             40          3.6     45
# 32           963   986      3.40             37          2.8     49
# 33           962  1010      4.50             38          2.9     39
# 34           965   997      6.70             36          2.6     41

# %%
from sklearn.tree import DecisionTreeRegressor
ecu_model = DecisionTreeRegressor()
ecu_model.fit(x,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(x, y, random_state=1)

# %%
ecu_model = DecisionTreeRegressor(random_state = 1)
ecu_model.fit(train_X,train_y)
ecu_predictions = ecu_model.predict(val_X)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(14,6))

sns.barplot(x = ecu['DISTANCE'], y = ecu.STEERINGANGLE)
plt.figure(figsize = (12,6))

sns.barplot(x = ecu['DISTANCELAT'],y = ecu.STEERINGANGLE)

# %%
plt.figure(figsize=(14,6))

sns.lineplot(x = ecu['DISTANCE'], y = ecu.STEERINGANGLE)
plt.figure(figsize = (12,6))
sns.lineplot(x = ecu['DISTANCELAT'], y = ecu.STEERINGANGLE)
sns.scatterplot(x = ecu['DISTANCELAT'],y = ecu.STEERINGANGLE)

# %%
plt.figure(figsize=(14,6))

sns.barplot(x = ecu['RPM'], y = ecu.STEERINGANGLE)

# %%
plt.figure(figsize = (14,6))
sns.barplot(x = ecu['SPEED'], y = ecu.STEERINGANGLE)
plt.figure(figsize = (14,6))
sns.lineplot(x = ecu['SPEED'], y = ecu.STEERINGANGLE)
plt.figure(figsize = (14,6))
sns.scatterplot(x = ecu['SPEED'], y = ecu.STEERINGANGLE)
